# %%
from pathlib import Path

from histokit.data.slides import get_slide_cls_for_path

# set up the paths
dataset_path = Path('../data/icaird/cervical_mini')
slide_path = dataset_path / 'slides' / 'IC-CX-00003-01.ome.tiff'

# get the slide class
slide_cls = get_slide_cls_for_path(slide_path)

# read a thumbnail
with slide_cls(slide_path) as slide:
    thumbs = slide.get_thumbnail_for_size(256, 256)

thumbs
# Out:
# array([[[227, 226, 231],
#         [227, 226, 230],
#         [227, 225, 230],
#         ...,
#         [226, 225, 230],
#         [227, 225, 230],
#         [226, 225, 230]],
#
#        [[227, 226, 230],
#         [227, 225, 230],
#         [226, 225, 230],
#         ...,
#         [227, 226, 230],
#         [226, 226, 230],
#         [226, 225, 229]],
#
#        [[227, 226, 230],
#         [227, 226, 230],
#         [227, 225, 230],
#         ...,
#         [227, 225, 230],
#         [226, 225, 229],
#         [226, 225, 229]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
